# %%
import pandas as pd
import numpy as np
df = pd.read_csv('title.basics.tsv', delimiter ='\t', encoding='utf-8', low_memory=False)
df1 = pd.read_csv('title.akas.tsv', delimiter ='\t', encoding='utf-8', low_memory=False)
df2 = pd.read_csv('title.crew.tsv', delimiter ='\t', encoding='utf-8', low_memory=False)
df3 = pd.read_csv('title.episode.tsv', delimiter ='\t', encoding='utf-8', low_memory=False)
df4 = pd.read_csv('name.basics.tsv', delimiter ='\t', encoding='utf-8', low_memory=False)
df5 = pd.read_csv('title.principals.tsv', delimiter ='\t', encoding='utf-8', low_memory=False)
df6 = pd.read_csv('title.ratings.tsv', delimiter ='\t', encoding='utf-8', low_memory=False)

# %% [markdown]
# ## Seggretting basic dataset on the basis of titletype

# %%
df.titleType.value_counts()
# Out:
# tvEpisode       3953453
# short            671435
# movie            514140
# video            225403
# tvSeries         161535
# tvMovie          126081
# tvMiniSeries      25283
# videoGame         23157
# tvSpecial         16843
# tvShort            9111
# Name: titleType, dtype: int64

# %% [markdown]
# ## Movie dataframe

# %%
dfMovie = df[(df["titleType"] == "short") | (df["titleType"] == "tvShort") | (df["titleType"] == "movie")
            | (df["titleType"] == "tvMovie")]
dfMovie["titleType"] = "movie"
# Out:
# /Users/thesarang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Series dataset

# %%
dfSeries = df[(df["titleType"] == "tvSeries") | (df["titleType"] == "tvMiniSeries")]
dfSeries["titleType"] = "series"
# Out:
# /Users/thesarang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Episode dataset

# %%
dfEpisode = df[(df["titleType"]== "tvEpisode")]
dfEpisode['titleType'] = 'episode'
# Out:
# /Users/thesarang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Merge episode, series, movie

# %%
dfBasicsNew = pd.concat([dfMovie, dfSeries, dfEpisode], ignore_index=True)
dfBasicsNew.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     movie              Carmencita              Carmencita
# 1  tt0000002     movie  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     movie          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     movie             Un bon bock             Un bon bock
# 4  tt0000005     movie        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# 3        0      1892      \N             \N           Animation,Short
# 4        0      1893      \N              1              Comedy,Short

# %%
dfBasicsNew.titleType.value_counts()
# Out:
# episode    3953453
# movie      1320767
# series      186818
# Name: titleType, dtype: int64

# %% [markdown]
# ## Merge new dataset with akas

# %%
titleakaswithbasics = pd.merge(df1, dfBasicsNew, left_on=['titleId'], right_on = ['tconst'])
titleakaswithbasics
# Out:
#            titleId  ordering  \
# 0        tt0000001         1
# 1        tt0000001         2
# 2        tt0000001         3
# 3        tt0000001         4
# 4        tt0000001         5
# 5        tt0000002         1
# 6        tt0000002         2
# 7        tt0000002         3
# 8        tt0000002         4
# 9        tt0000002         5
# 10       tt0000002         6
# 11       tt0000003         1
# 12       tt0000003         2
# 13       tt0000003         3
# 14       tt0000003         4
# 15       tt0000003         5
# 16       tt0000003         6
# 17       tt0000004         1
# 18       tt0000004         2
# 19       tt0000004         3
# 20       tt0000004         4
# 21       tt0000004         5
# 22       tt0000004         6
# 23       tt0000005         1
# 24       tt0000005         2
# 25       tt0000005         3
# 26       tt0000005         4
# 27       tt0000005         5
# 28       tt0000005         6
# 29       tt0000005         7
# ...            ...       ...
# 3309806  tt9914254         1
# 3309807  tt9914254         2
# 3309808  tt9914254         3
# 3309809  tt9914314         1
# 3309810  tt9914314         2
# 3309811  tt9914314         3
# 3309812  tt9914708         1
# 3309813  tt9914708         2
# 3309814  tt9914708         3
# 3309815  tt9915022         1
# 3309816  tt9915022         2
# 3309817  tt9915022         3
# 3309818  tt9915436         1
# 3309819  tt9915436         2
# 3309820  tt9915520         1
# 3309821  tt9915520         2
# 3309822  tt9915520         3
# 3309823  tt9915592         1
# 3309824  tt9915592         2
# 3309825  tt9916170         1
# 3309826  tt9916170         2
# 3309827  tt9916170         3
# 3309828  tt9916174         1
# 3309829  tt9916174         2
# 3309830  tt9916174         3
# 3309831  tt9916192         1
# 3309832  tt9916192         2
# 3309833  tt9916192         3
# 3309834  tt9916460         1
# 3309835  tt9916460         2
#
#                                                      title region language  \
# 0                                Carmencita - spanyol tánc     HU       \N
# 1                                               Καρμενσίτα     GR       \N
# 2                                               Карменсита     RU       \N
# 3                                               Carmencita     US       \N
# 4                                               Carmencita     \N       \N
# 5                                   Le clown et ses chiens     \N       \N
# 6                                        A bohóc és kutyái     HU       \N
# 7                                   Le clown et ses chiens     FR       \N
# 8                                    Clovnul si cainii sai     RO       \N
# 9                                       Клоун и его собаки     RU       \N
# 10                                  The Clown and His Dogs     US       \N
# 11                                        Sarmanul Pierrot     RO       \N
# 12                                         Szegény Pierrot     HU       \N
# 13                                            Бедный Пьеро     RU       \N
# 14                                          Pauvre Pierrot     \N       \N
# 15                                            Poor Pierrot     \N       \N
# 16                                          Pauvre Pierrot     FR       \N
# 17                                             Un bon bock     \N       \N
# 18                                          Un ţap de bere     RO       \N
# 19                                             Un bon bock     FR       \N
# 20                                      Полная кружка пива     RU       \N
# 21                                             A Good Beer     \N       \N
# 22                                        Egy jó pohár sör     HU       \N
# 23                                     Blacksmithing Scene     US       \N
# 24                                           Сцена в кузне     RU       \N
# 25                                         Blacksmith Shop     GB       \N
# 26                                     Blacksmith Scene #1     US       \N
# 27                                           Blacksmithing     US       \N
# 28                                         A patkolókovács     HU       \N
# 29                                        Blacksmith Scene     US       \N
# ...                                                    ...    ...      ...
# 3309806                                  Kirsebæreventyret     \N       \N
# 3309807                                      A Cherry Tale    XWW       en
# 3309808                                  Kirsebæreventyret     DK       \N
# 3309809  Die Macht der Bücher: Französischsprachige Lit...     DE       \N
# 3309810  La force des livres: Écrire en français aujour...     FR       \N
# 3309811  Die Macht der Bücher: Französischsprachige Lit...     \N       \N
# 3309812                          Popp- og rokksaga Íslands     \N       \N
# 3309813                                     Rock Islandica    XWW       en
# 3309814                          Popp- og rokksaga Íslands     IS       \N
# 3309815                                      Yarali Kuslar     TR       \N
# 3309816                                      Yarali Kuslar     \N       \N
# 3309817                                      Wounded Birds    XWW       en
# 3309818                                   Life in Movement     US       \N
# 3309819                                  Vida em Movimento     \N       \N
# 3309820                             Fascism i en svart bil     \N       \N
# 3309821                          Fasismia mustassa autossa     FI       \N
# 3309822                             Fascism i en svart bil     FI       \N
# 3309823                                  A Husband to Rent    XWW       en
# 3309824                                   Shohar-e kerayei     \N       \N
# 3309825                                           O Ensaio     BR       \N
# 3309826                                      The Rehearsal    XWW       en
# 3309827                                           O Ensaio     \N       \N
# 3309828                                       Kleiderglück     \N       \N
# 3309829                                       Strange Love    XWW       en
# 3309830                                       Kleiderglück     DE       \N
# 3309831  Danielle Darrieux: Filmstar mit dem frechen Etwas     DE       \N
# 3309832         Danielle Darrieux: Il est poli d'être gai!     FR       \N
# 3309833         Danielle Darrieux: Il est poli d'être gai!     \N       \N
# 3309834                                           Ροζ Ταξί     GR       \N
# 3309835                                          Pink Taxi     \N       \N
#
#                types                  attributes isOriginalTitle     tconst  \
# 0        imdbDisplay                          \N               0  tt0000001
# 1                 \N                          \N               0  tt0000001
# 2                 \N                          \N               0  tt0000001
# 3                 \N                          \N               0  tt0000001
# 4           original                          \N               1  tt0000001
# 5           original                          \N               1  tt0000002
# 6        imdbDisplay                          \N               0  tt0000002
# 7                 \N                          \N               0  tt0000002
# 8        imdbDisplay                          \N               0  tt0000002
# 9                 \N                          \N               0  tt0000002
# 10                \N       literal English title               0  tt0000002
# 11       imdbDisplay                          \N               0  tt0000003
# 12       imdbDisplay                          \N               0  tt0000003
# 13                \N                          \N               0  tt0000003
# 14          original                          \N               1  tt0000003
# 15                \N                          \N               0  tt0000003
# 16                \N                          \N               0  tt0000003
# 17          original                          \N               1  tt0000004
# 18                \N                          \N               0  tt0000004
# 19                \N                          \N               0  tt0000004
# 20                \N                          \N               0  tt0000004
# 21                \N                          \N               0  tt0000004
# 22       imdbDisplay                          \N               0  tt0000004
# 23       alternative                          \N               0  tt0000005
# 24                \N                          \N               0  tt0000005
# 25                \N  informal alternative title               0  tt0000005
# 26       alternative                          \N               0  tt0000005
# 27                \N  informal alternative title               0  tt0000005
# 28       imdbDisplay                          \N               0  tt0000005
# 29                \N                          \N               0  tt0000005
# ...              ...                         ...             ...        ...
# 3309806     original                          \N               1  tt9914254
# 3309807  imdbDisplay                          \N               0  tt9914254
# 3309808           \N                          \N               0  tt9914254
# 3309809           \N                          \N               0  tt9914314
# 3309810  imdbDisplay                          \N               0  tt9914314
# 3309811     original                          \N               1  tt9914314
# 3309812     original                          \N               1  tt9914708
# 3309813  alternative                          \N               0  tt9914708
# 3309814           \N                          \N               0  tt9914708
# 3309815           \N                          \N               0  tt9915022
# 3309816     original                          \N               1  tt9915022
# 3309817  alternative                          \N               0  tt9915022
# 3309818  alternative                          \N               0  tt9915436
# 3309819     original                          \N               1  tt9915436
# 3309820     original                          \N               1  tt9915520
# 3309821  alternative                          \N               0  tt9915520
# 3309822           \N                          \N               0  tt9915520
# 3309823  imdbDisplay                          \N               0  tt9915592
# 3309824     original                          \N               1  tt9915592
# 3309825           \N                          \N               0  tt9916170
# 3309826  imdbDisplay                          \N               0  tt9916170
# 3309827     original                          \N               1  tt9916170
# 3309828     original                          \N               1  tt9916174
# 3309829           \N      informal English title               0  tt9916174
# 3309830           \N                          \N               0  tt9916174
# 3309831  imdbDisplay                          \N               0  tt9916192
# 3309832           \N                          \N               0  tt9916192
# 3309833     original                          \N               1  tt9916192
# 3309834           \N                          \N               0  tt9916460
# 3309835     original                          \N               1  tt9916460
#
#         titleType                                       primaryTitle  \
# 0           movie                                         Carmencita
# 1           movie                                         Carmencita
# 2           movie                                         Carmencita
# 3           movie                                         Carmencita
# 4           movie                                         Carmencita
# 5           movie                             Le clown et ses chiens
# 6           movie                             Le clown et ses chiens
# 7           movie                             Le clown et ses chiens
# 8           movie                             Le clown et ses chiens
# 9           movie                             Le clown et ses chiens
# 10          movie                             Le clown et ses chiens
# 11          movie                                     Pauvre Pierrot
# 12          movie                                     Pauvre Pierrot
# 13          movie                                     Pauvre Pierrot
# 14          movie                                     Pauvre Pierrot
# 15          movie                                     Pauvre Pierrot
# 16          movie                                     Pauvre Pierrot
# 17          movie                                        Un bon bock
# 18          movie                                        Un bon bock
# 19          movie                                        Un bon bock
# 20          movie                                        Un bon bock
# 21          movie                                        Un bon bock
# 22          movie                                        Un bon bock
# 23          movie                                   Blacksmith Scene
# 24          movie                                   Blacksmith Scene
# 25          movie                                   Blacksmith Scene
# 26          movie                                   Blacksmith Scene
# 27          movie                                   Blacksmith Scene
# 28          movie                                   Blacksmith Scene
# 29          movie                                   Blacksmith Scene
# ...           ...                                                ...
# 3309806     movie                                      A Cherry Tale
# 3309807     movie                                      A Cherry Tale
# 3309808     movie                                      A Cherry Tale
# 3309809     movie  Die Macht der Bücher: Französischsprachige Lit...
# 3309810     movie  Die Macht der Bücher: Französischsprachige Lit...
# 3309811     movie  Die Macht der Bücher: Französischsprachige Lit...
# 3309812    series                          Popp- og rokksaga Íslands
# 3309813    series                          Popp- og rokksaga Íslands
# 3309814    series                          Popp- og rokksaga Íslands
# 3309815    series                                      Yarali Kuslar
# 3309816    series                                      Yarali Kuslar
# 3309817    series                                      Yarali Kuslar
# 3309818     movie                                  Vida em Movimento
# 3309819     movie                                  Vida em Movimento
# 3309820     movie                             Fascism i en svart bil
# 3309821     movie                             Fascism i en svart bil
# 3309822     movie                             Fascism i en svart bil
# 3309823     movie                                  A Husband to Rent
# 3309824     movie                                  A Husband to Rent
# 3309825     movie                                      The Rehearsal
# 3309826     movie                                      The Rehearsal
# 3309827     movie                                      The Rehearsal
# 3309828     movie                                       Kleiderglück
# 3309829     movie                                       Kleiderglück
# 3309830     movie                                       Kleiderglück
# 3309831     movie         Danielle Darrieux: Il est poli d'être gai!
# 3309832     movie         Danielle Darrieux: Il est poli d'être gai!
# 3309833     movie         Danielle Darrieux: Il est poli d'être gai!
# 3309834     movie                                          Pink Taxi
# 3309835     movie                                          Pink Taxi
#
#                                              originalTitle  isAdult startYear  \
# 0                                               Carmencita        0      1894
# 1                                               Carmencita        0      1894
# 2                                               Carmencita        0      1894
# 3                                               Carmencita        0      1894
# 4                                               Carmencita        0      1894
# 5                                   Le clown et ses chiens        0      1892
# 6                                   Le clown et ses chiens        0      1892
# 7                                   Le clown et ses chiens        0      1892
# 8                                   Le clown et ses chiens        0      1892
# 9                                   Le clown et ses chiens        0      1892
# 10                                  Le clown et ses chiens        0      1892
# 11                                          Pauvre Pierrot        0      1892
# 12                                          Pauvre Pierrot        0      1892
# 13                                          Pauvre Pierrot        0      1892
# 14                                          Pauvre Pierrot        0      1892
# 15                                          Pauvre Pierrot        0      1892
# 16                                          Pauvre Pierrot        0      1892
# 17                                             Un bon bock        0      1892
# 18                                             Un bon bock        0      1892
# 19                                             Un bon bock        0      1892
# 20                                             Un bon bock        0      1892
# 21                                             Un bon bock        0      1892
# 22                                             Un bon bock        0      1892
# 23                                        Blacksmith Scene        0      1893
# 24                                        Blacksmith Scene        0      1893
# 25                                        Blacksmith Scene        0      1893
# 26                                        Blacksmith Scene        0      1893
# 27                                        Blacksmith Scene        0      1893
# 28                                        Blacksmith Scene        0      1893
# 29                                        Blacksmith Scene        0      1893
# ...                                                    ...      ...       ...
# 3309806                                  Kirsebæreventyret        0      2019
# 3309807                                  Kirsebæreventyret        0      2019
# 3309808                                  Kirsebæreventyret        0      2019
# 3309809  Die Macht der Bücher: Französischsprachige Lit...        0      2017
# 3309810  Die Macht der Bücher: Französischsprachige Lit...        0      2017
# 3309811  Die Macht der Bücher: Französischsprachige Lit...        0      2017
# 3309812                          Popp- og rokksaga Íslands        0      2015
# 3309813                          Popp- og rokksaga Íslands        0      2015
# 3309814                          Popp- og rokksaga Íslands        0      2015
# 3309815                                      Yarali Kuslar        0      2019
# 3309816                                      Yarali Kuslar        0      2019
# 3309817                                      Yarali Kuslar        0      2019
# 3309818                                  Vida em Movimento        0      2019
# 3309819                                  Vida em Movimento        0      2019
# 3309820                             Fascism i en svart bil        0      2019
# 3309821                             Fascism i en svart bil        0      2019
# 3309822                             Fascism i en svart bil        0      2019
# 3309823                                   Shohar-e kerayei        0      1974
# 3309824                                   Shohar-e kerayei        0      1974
# 3309825                                           O Ensaio        0      2019
# 3309826                                           O Ensaio        0      2019
# 3309827                                           O Ensaio        0      2019
# 3309828                                       Kleiderglück        0      2018
# 3309829                                       Kleiderglück        0      2018
# 3309830                                       Kleiderglück        0      2018
# 3309831         Danielle Darrieux: Il est poli d'être gai!        0      2019
# 3309832         Danielle Darrieux: Il est poli d'être gai!        0      2019
# 3309833         Danielle Darrieux: Il est poli d'être gai!        0      2019
# 3309834                                          Pink Taxi        0      2019
# 3309835                                          Pink Taxi        0      2019
#
#         endYear runtimeMinutes                    genres
# 0            \N              1         Documentary,Short
# 1            \N              1         Documentary,Short
# 2            \N              1         Documentary,Short
# 3            \N              1         Documentary,Short
# 4            \N              1         Documentary,Short
# 5            \N              5           Animation,Short
# 6            \N              5           Animation,Short
# 7            \N              5           Animation,Short
# 8            \N              5           Animation,Short
# 9            \N              5           Animation,Short
# 10           \N              5           Animation,Short
# 11           \N              4  Animation,Comedy,Romance
# 12           \N              4  Animation,Comedy,Romance
# 13           \N              4  Animation,Comedy,Romance
# 14           \N              4  Animation,Comedy,Romance
# 15           \N              4  Animation,Comedy,Romance
# 16           \N              4  Animation,Comedy,Romance
# 17           \N             \N           Animation,Short
# 18           \N             \N           Animation,Short
# 19           \N             \N           Animation,Short
# 20           \N             \N           Animation,Short
# 21           \N             \N           Animation,Short
# 22           \N             \N           Animation,Short
# 23           \N              1              Comedy,Short
# 24           \N              1              Comedy,Short
# 25           \N              1              Comedy,Short
# 26           \N              1              Comedy,Short
# 27           \N              1              Comedy,Short
# 28           \N              1              Comedy,Short
# 29           \N              1              Comedy,Short
# ...         ...            ...                       ...
# 3309806      \N             85               Documentary
# 3309807      \N             85               Documentary
# 3309808      \N             85               Documentary
# 3309809      \N             53               Documentary
# 3309810      \N             53               Documentary
# 3309811      \N             53               Documentary
# 3309812    2015            116               Documentary
# 3309813    2015            116               Documentary
# 3309814    2015            116               Documentary
# 3309815      \N             \N                     Drama
# 3309816      \N             \N                     Drama
# 3309817      \N             \N                     Drama
# 3309818      \N             70               Documentary
# 3309819      \N             70               Documentary
# 3309820      \N             54               Documentary
# 3309821      \N             54               Documentary
# 3309822      \N             54               Documentary
# 3309823      \N             \N                    Comedy
# 3309824      \N             \N                    Comedy
# 3309825      \N             \N                     Drama
# 3309826      \N             \N                     Drama
# 3309827      \N             \N                     Drama
# 3309828      \N             14                     Short
# 3309829      \N             14                     Short
# 3309830      \N             14                     Short
# 3309831      \N             53                 Biography
# 3309832      \N             53                 Biography
# 3309833      \N             53                 Biography
# 3309834      \N             \N                    Comedy
# 3309835      \N             \N                    Comedy
#
# [3309836 rows x 17 columns]

# %%
#fetching series, movie and episode values from titleType
akas_series = titleakaswithbasics[titleakaswithbasics["titleType"] == "series"]
akas_movie = titleakaswithbasics[titleakaswithbasics["titleType"] == "movie"]
akas_episode = titleakaswithbasics[titleakaswithbasics["titleType"] == "episode"]

# %% [markdown]
# ## droping columns of basics

# %%
series_alias = akas_series.drop(columns=["tconst", "titleType", "primaryTitle", "originalTitle", "isAdult",
                           "startYear", "endYear", "runtimeMinutes", "genres"], axis = 1)
movie_alias = akas_movie.drop(columns=["tconst", "titleType", "primaryTitle", "originalTitle", "isAdult",
                           "startYear", "endYear", "runtimeMinutes", "genres"], axis = 1)                         
episode_alias = akas_episode.drop(columns=["tconst", "titleType", "primaryTitle", "originalTitle", "isAdult",
                           "startYear", "endYear", "runtimeMinutes", "genres"], axis = 1)

# %%
# Remove Attributes, language

# %%
movie_alias.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1  Carmencita - spanyol tánc     HU       \N
# 1  tt0000001         2                 Καρμενσίτα     GR       \N
# 2  tt0000001         3                 Карменсита     RU       \N
# 3  tt0000001         4                 Carmencita     US       \N
# 4  tt0000001         5                 Carmencita     \N       \N
#
#          types attributes isOriginalTitle
# 0  imdbDisplay         \N               0
# 1           \N         \N               0
# 2           \N         \N               0
# 3           \N         \N               0
# 4     original         \N               1

# %% [markdown]
# # merging episode dataset with of episodes column of title.basics with ratings

# %%
df_episode_new = pd.merge(df3, dfEpisode, left_on=['tconst'], right_on = ['tconst'])
df_episode_new.drop(columns=["genres"], axis = 1, inplace=True)
df_episode_new.head()
# Out:
#       tconst parentTconst seasonNumber episodeNumber titleType  \
# 0  tt0041951    tt0041038            1             9   episode
# 1  tt0042816    tt0989125            1            17   episode
# 2  tt0042889    tt0989125           \N            \N   episode
# 3  tt0043426    tt0040051            3            42   episode
# 4  tt0043631    tt0989125            2            16   episode
#
#                         primaryTitle                      originalTitle  \
# 0                     The Tenderfeet                     The Tenderfeet
# 1                            Othello                            Othello
# 2  The Tragedy of King Richard II/II  The Tragedy of King Richard II/II
# 3                         Coriolanus                         Coriolanus
# 4           The Life of King Henry V           The Life of King Henry V
#
#    isAdult startYear endYear runtimeMinutes
# 0        0      1949      \N             30
# 1        0      1950      \N            135
# 2        0      1950      \N            145
# 3        0      1951      \N             60
# 4        0      1951      \N            133

# %%
df_episode_new = pd.merge(df_episode_new, df6, on='tconst', how = "left")
df_episode_new.head()
# Out:
#       tconst parentTconst seasonNumber episodeNumber titleType  \
# 0  tt0041951    tt0041038            1             9   episode
# 1  tt0042816    tt0989125            1            17   episode
# 2  tt0042889    tt0989125           \N            \N   episode
# 3  tt0043426    tt0040051            3            42   episode
# 4  tt0043631    tt0989125            2            16   episode
#
#                         primaryTitle                      originalTitle  \
# 0                     The Tenderfeet                     The Tenderfeet
# 1                            Othello                            Othello
# 2  The Tragedy of King Richard II/II  The Tragedy of King Richard II/II
# 3                         Coriolanus                         Coriolanus
# 4           The Life of King Henry V           The Life of King Henry V
#
#    isAdult startYear endYear runtimeMinutes  averageRating  numVotes
# 0        0      1949      \N             30            7.4      36.0
# 1        0      1950      \N            135            NaN       NaN
# 2        0      1950      \N            145            NaN       NaN
# 3        0      1951      \N             60            NaN       NaN
# 4        0      1951      \N            133            NaN       NaN

# %%
df6[df6["tconst"] == "tt0041951"]
# Out:
#           tconst  averageRating  numVotes
# 21872  tt0041951            7.4        36

# %% [markdown]
# ## segregating movie and series wrt title type

# %%
dfBasicsNew_movie = dfBasicsNew[dfBasicsNew["titleType"] == "movie"]
dfBasicsNew_series = dfBasicsNew[dfBasicsNew["titleType"] == "series"]
print(dfBasicsNew_movie.shape, dfBasicsNew_series.shape)
# Out:
# (1320767, 9) (186818, 9)

# %%
#for movies
# print (dfBasicsNew_movie["genres"].unique().tolist())
df_movie_genre = dfBasicsNew_movie[["tconst", "genres"]]
df_movie_genre = df_movie_genre[df_movie_genre["genres"] != "\\N"]
df_movie_genre = pd.DataFrame(df_movie_genre.genres.str.split(',')
                                          .tolist(), index=df_movie_genre.tconst).stack()
df_movie_genre = df_movie_genre.reset_index()[['tconst', 0]] 
df_movie_genre.columns = ['tconst', 'genres']
df_movie_genre.head()
# Out:
#       tconst       genres
# 0  tt0000001  Documentary
# 1  tt0000001        Short
# 2  tt0000002    Animation
# 3  tt0000002        Short
# 4  tt0000003    Animation

# %%
#for series
df_series_genre = dfBasicsNew_series[["tconst", "genres"]]
df_series_genre = df_series_genre[df_series_genre["genres"] != "\\N"]
df_series_genre = pd.DataFrame(df_series_genre.genres.str.split(',')
                                          .tolist(), index=df_series_genre.tconst).stack()
df_series_genre = df_series_genre.reset_index()[['tconst', 0]] 
df_series_genre.columns = ['tconst', 'genres']
df_series_genre.head()
# Out:
#       tconst     genres
# 0  tt0039120     Family
# 1  tt0039120  Game-Show
# 2  tt0039121     Family
# 3  tt0039122     Comedy
# 4  tt0039122      Music

# %% [markdown]
# ## name.basics dataset

# %%
df4["primaryProfession"].replace(np.nan, "None", inplace = True)
df42 = pd.DataFrame(df4.primaryProfession.str.split(',')
                                         .tolist(), index=df4.nconst).stack()
df42 = df42.reset_index()[['nconst', 0]] 
df42.rename(columns = {0: 'primaryProfession'}, inplace=True)

# %%
df4_notNone = df4[df4["primaryProfession"] != "None"]

# %%
df4_final = pd.merge(df4_notNone, df42, left_on=['nconst'], right_on = ['nconst'])
df4_final.drop(columns = ["primaryProfession_x"], axis = True, inplace=True)
df4_final.rename(columns = {"primaryProfession_y": 'primaryProfession'}, inplace=True)

# %%
df4_final.head()
# Out:
#       nconst    primaryName birthYear deathYear  \
# 0  nm0000001   Fred Astaire      1899      1987
# 1  nm0000001   Fred Astaire      1899      1987
# 2  nm0000001   Fred Astaire      1899      1987
# 3  nm0000002  Lauren Bacall      1924      2014
# 4  nm0000002  Lauren Bacall      1924      2014
#
#                             knownForTitles primaryProfession
# 0  tt0043044,tt0053137,tt0050419,tt0072308        soundtrack
# 1  tt0043044,tt0053137,tt0050419,tt0072308             actor
# 2  tt0043044,tt0053137,tt0050419,tt0072308     miscellaneous
# 3  tt0038355,tt0071877,tt0117057,tt0037382           actress
# 4  tt0038355,tt0071877,tt0117057,tt0037382        soundtrack

# %%
df4_final_actor_actress = df4_final[(df4_final["primaryProfession"] == "actor") | 
                                    (df4_final["primaryProfession"] == "actress")]
df4_final_director = df4_final[df4_final["primaryProfession"] == "director"]
df4_final_writer = df4_final[df4_final["primaryProfession"] == "writer"]

# %%
df4_final_actor_actress["gender"] = "None"
# Out:
# /Users/thesarang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df4_final_actor_actress.loc[df4_final_actor_actress['primaryProfession'] == 'actor', 'gender'] = 'male'
df4_final_actor_actress.loc[df4_final_actor_actress['primaryProfession'] == 'actress', 'gender'] = 'female'
df4_final_actor_actress
# Out:
# /Users/thesarang/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/thesarang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/thesarang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              nconst                primaryName birthYear deathYear  \
# 1         nm0000001               Fred Astaire      1899      1987
# 3         nm0000002              Lauren Bacall      1924      2014
# 5         nm0000003            Brigitte Bardot      1934        \N
# 8         nm0000004               John Belushi      1949      1982
# 13        nm0000005             Ingmar Bergman      1918      2007
# 14        nm0000006             Ingrid Bergman      1915      1982
# 17        nm0000007            Humphrey Bogart      1899      1957
# 20        nm0000008              Marlon Brando      1924      2004
# 23        nm0000009             Richard Burton      1925      1984
# 26        nm0000010               James Cagney      1899      1986
# 29        nm0000011                Gary Cooper      1901      1961
# 32        nm0000012                Bette Davis      1908      1989
# 36        nm0000013                  Doris Day      1922        \N
# 38        nm0000014        Olivia de Havilland      1916        \N
# 40        nm0000015                 James Dean      1931      1955
# 46        nm0000017           Marlene Dietrich      1901      1992
# 48        nm0000018               Kirk Douglas      1916        \N
# 54        nm0000020                Henry Fonda      1905      1982
# 57        nm0000021              Joan Fontaine      1917      2013
# 60        nm0000022                Clark Gable      1901      1960
# 64        nm0000023               Judy Garland      1922      1969
# 65        nm0000024               John Gielgud      1904      2000
# 71        nm0000026                 Cary Grant      1904      1986
# 74        nm0000027              Alec Guinness      1914      2000
# 77        nm0000028              Rita Hayworth      1918      1987
# 80        nm0000029          Margaux Hemingway      1954      1996
# 82        nm0000030             Audrey Hepburn      1929      1993
# 84        nm0000031          Katharine Hepburn      1907      2003
# 87        nm0000032            Charlton Heston      1923      2008
# 90        nm0000033           Alfred Hitchcock      1899      1980
# ...             ...                        ...       ...       ...
# 10320657  nm9993626                      Tanya        \N        \N
# 10320658  nm9993628                Anne Hansen        \N        \N
# 10320659  nm9993629                       Anna        \N        \N
# 10320660  nm9993631                     Amilia        \N        \N
# 10320661  nm9993634                    Beverly        \N        \N
# 10320662  nm9993635            Linda Georgeson        \N        \N
# 10320663  nm9993636                Adam French        \N        \N
# 10320664  nm9993637                      Jessy        \N        \N
# 10320665  nm9993639                       Nyla        \N        \N
# 10320672  nm9993648                Devin Kirby        \N        \N
# 10320674  nm9993650            Marcin Balcerak        \N        \N
# 10320675  nm9993651               Marcin Merda        \N        \N
# 10320676  nm9993652           Kamil Borowiecki        \N        \N
# 10320677  nm9993653          Marek Jastrzebski        \N        \N
# 10320679  nm9993654         Mariusz Paszkowski        \N        \N
# 10320680  nm9993655                Piotr Kumor        \N        \N
# 10320681  nm9993656              Jerzy Ciurlok        \N        \N
# 10320696  nm9993680  Christopher-Lawson Palmer        \N        \N
# 10320697  nm9993681               Saiya Palmer        \N        \N
# 10320698  nm9993682               Cheryl Clark        \N        \N
# 10320699  nm9993683              Lula Langston        \N        \N
# 10320702  nm9993686              Yukari Funaki        \N        \N
# 10320703  nm9993687                 Hiroko Ide        \N        \N
# 10320705  nm9993693            Anketa Maharana        \N        \N
# 10320706  nm9993694             Chinmay Mishra        \N        \N
# 10320709  nm9993697             Zakariya Ganim        \N        \N
# 10320710  nm9993698                  Sebi John        \N        \N
# 10320711  nm9993699                 Dani Jacob        \N        \N
# 10320712  nm9993700                 Sexy Angel        \N        \N
# 10320713  nm9993701           Sanjai Kuriakose        \N        \N
#
#                                    knownForTitles primaryProfession  gender
# 1         tt0043044,tt0053137,tt0050419,tt0072308             actor    male
# 3         tt0038355,tt0071877,tt0117057,tt0037382           actress  female
# 5         tt0059956,tt0049189,tt0054452,tt0057345           actress  female
# 8         tt0077975,tt0078723,tt0080455,tt0072562             actor    male
# 13        tt0083922,tt0050976,tt0069467,tt0050986             actor    male
# 14        tt0036855,tt0038109,tt0038787,tt0071877           actress  female
# 17        tt0037382,tt0034583,tt0033870,tt0043265             actor    male
# 20        tt0070849,tt0047296,tt0068646,tt0078788             actor    male
# 23        tt0087803,tt0057877,tt0059749,tt0061184             actor    male
# 26        tt0035575,tt0055256,tt0029870,tt0031867             actor    male
# 29        tt0027996,tt0034167,tt0035211,tt0044706             actor    male
# 32        tt0031210,tt0056687,tt0042192,tt0035140           actress  female
# 36        tt0048317,tt0053172,tt0060463,tt0055100           actress  female
# 38        tt0041452,tt0029843,tt0031381,tt0040806           actress  female
# 40        tt0048545,tt0048028,tt0045458,tt0049261             actor    male
# 46        tt0055031,tt0052311,tt0040367,tt0051201           actress  female
# 48        tt0052365,tt0049456,tt0080736,tt0054331             actor    male
# 54        tt0032551,tt0050083,tt0064116,tt0082846             actor    male
# 57        tt0039504,tt0034248,tt0036969,tt0032976           actress  female
# 60        tt0052278,tt0031381,tt0026752,tt0025316             actor    male
# 64        tt0037059,tt0032138,tt0055031,tt0047522           actress  female
# 65        tt0071877,tt0045943,tt0082031,tt0117631             actor    male
# 71        tt0056923,tt0036613,tt0048728,tt0053125             actor    male
# 74        tt0050212,tt0051739,tt0041546,tt0076759             actor    male
# 77        tt0040552,tt0036723,tt0038559,tt0040525           actress  female
# 80        tt0077800,tt0074802,tt0110138,tt0102122           actress  female
# 82        tt0046250,tt0056923,tt0054698,tt0058385           actress  female
# 84        tt0082846,tt0032904,tt0043265,tt0063227           actress  female
# 87        tt0052618,tt0063442,tt0070723,tt0049833             actor    male
# 90        tt0053125,tt0052357,tt0054215,tt0030341             actor    male
# ...                                           ...               ...     ...
# 10320657                                tt4862524           actress  female
# 10320658                                       \N             actor    male
# 10320659                                       \N           actress  female
# 10320660                                       \N           actress  female
# 10320661                                       \N           actress  female
# 10320662                                       \N           actress  female
# 10320663                                tt6164916             actor    male
# 10320664                                       \N           actress  female
# 10320665                                       \N           actress  female
# 10320672                                tt4460424             actor    male
# 10320674                                tt8739208             actor    male
# 10320675                                tt8739208             actor    male
# 10320676                                tt8739208             actor    male
# 10320677                      tt8739208,tt8308330             actor    male
# 10320679                                tt8739208             actor    male
# 10320680                                tt8739208             actor    male
# 10320681                                tt8739208             actor    male
# 10320696                                tt8295580             actor    male
# 10320697                                tt8295580           actress  female
# 10320698                                tt8744086           actress  female
# 10320699                                tt8744086             actor    male
# 10320702                                       \N           actress  female
# 10320703                                tt7170282           actress  female
# 10320705                                tt8737752           actress  female
# 10320706                                tt8737752             actor    male
# 10320709                                       \N             actor    male
# 10320710                                tt8736744             actor    male
# 10320711                                tt8736744             actor    male
# 10320712                                       \N           actress  female
# 10320713                                tt8736744             actor    male
#
# [3514946 rows x 7 columns]

# %% [markdown]
# ## crew dataset

# %%
df2 = pd.read_csv('title.crew.tsv', delimiter ='\t', encoding='utf-8', low_memory=False)
df2.head()

# %%
df2_writers = df2[(df2["writers"] != "\\N")]
print(df2_writers["writers"].unique().tolist())

# %%
df2_writers.head()

# %%
df2_writers = pd.DataFrame(df2_writers["writers"].str.split(',').tolist(), index=df2_writers.tconst).stack()
pd.Series.to_frame(df2_writers).reset_index()
# titlebasicgenre.columns = ['tconst', 'writers'] # renaming var1
# titlebasicgenre

# %% [markdown]
# ## Principals Dataset

# %%
df5 = pd.read_csv('title.principals.tsv', delimiter ='\t', encoding='utf-8', low_memory=False)

# %%
df_principal_basecnew = pd.merge(dfBasicsNew, df5, left_on=['tconst'], right_on = ['tconst'])

# %%
df_principal_basecnew.titleType.value_counts()

# %%
df_principal_movie = df_principal_basecnew[(df_principal_basecnew['titleType']=='movie')]
df_principal_series = df_principal_basecnew[(df_principal_basecnew['titleType']=='series')]
df_principal_episode = df_principal_basecnew[(df_principal_basecnew['titleType']=='episode')]

# %% [markdown]
# ## For movies

# %%
dfMovieRelation = df_principal_movie[(df_principal_movie['category']=='actor') | 
                                         (df_principal_movie['category']=='actress') |
                                         (df_principal_movie['category']=='writer') |
                                         (df_principal_movie['category']=='director')]
dfMovieRelation.drop(columns = ['titleType','primaryTitle', 'originalTitle','isAdult','startYear','endYear',
                                     'runtimeMinutes', "job", "genres"], axis = 1, inplace = True)

# %%
# Acted by relation set between actor and movie
dfActorMovieRelation = dfMovieRelation[(dfMovieRelation["category"] == "actor") | 
                                       (dfMovieRelation["category"] == "actress")]
dfActorMovieRelation.head()

# %%
# Directed by relation set between director and movie
dfDirectorMovieRelation = dfMovieRelation[(dfMovieRelation["category"] == "director")]
dfDirectorMovieRelation.head()

# %%
# Directed by relation set between writer and movie
dfWriterMovieRelation = dfMovieRelation[(dfMovieRelation["category"] == "writer")]
dfWriterMovieRelation.head()

# %% [markdown]
# ## For series

# %%
dfSeriesRelation = df_principal_series[(df_principal_series['category']=='actor') | 
                                         (df_principal_series['category']=='actress') |
                                         (df_principal_series['category']=='writer') |
                                         (df_principal_series['category']=='director')]
dfSeriesRelation.drop(columns = ['titleType','primaryTitle', 'originalTitle','isAdult','startYear','endYear',
                                     'runtimeMinutes', "job", "genres"], axis = 1, inplace = True)

# %%
# Acted by relation set between actor and series
dfActorSeriesRelation = dfSeriesRelation[(dfSeriesRelation["category"] == "actor") | 
                                       (dfSeriesRelation["category"] == "actress")]
dfActorSeriesRelation.head()

# %%
# Acted by relation set between director and series
dfDirectorSeriesRelation = dfSeriesRelation[(dfSeriesRelation["category"] == "director")]
dfDirectorSeriesRelation.head()

# %%
# Acted by relation set between writer and series
dfWriterSeriesRelation = dfSeriesRelation[(dfSeriesRelation["category"] == "writer")]
dfWriterSeriesRelation.head()

# %% [markdown]
# ## Adding ratings to Movie, series and episodes

# %%
# dfMovieNew = pd.merge(dfMovie, df6, how = "left", left_on=['tconst'], right_on = ['tconst'])
# dfSeriesNew = pd.merge(dfSeries, df6, how = "left", left_on=['tconst'], right_on = ['tconst'])
dfEpisodeNew = pd.merge(dfEpisode, df6, how = "left", left_on=['tconst'], right_on = ['tconst'])

# %%
dfEpisodeNew

# %%
# dfMovieNew
dfSeriesNew

# %% [markdown]
# ## Dropping columns and converting datasets to csv files - basics + ratings

# %% [markdown]
# ### Dropping endYear,  titleType, Genre

# %%
dfMovieNewFinal = dfMovieNew.drop(columns=["endYear", "titleType", "genres"], axis = 1)
dfMovieNewFinal.to_csv("Final CSV Files/Movie.tsv", encoding="utf-8", sep="\t", index=False)

# %%
dfSeriesNewFinal = dfSeriesNew.drop(columns=["endYear", "titleType", "genres", "runtimeMinutes"], axis = 1)
dfSeriesNewFinal.to_csv("Final CSV Files/Series.tsv", encoding="utf-8", sep="\t", index=False)

# %%
dfEpisodeNewFinal = df_episode_new.drop(columns=["endYear", "titleType","runtimeMinutes"], axis = 1)
dfEpisodeNewFinal.to_csv("Final CSV Files/Episode.tsv", encoding="utf-8", sep="\t", index=False)

# %%
dfEpisodeNewFinal.head(5)

# %%
df_episode_new.head(5)

# %%
df_episode_new

# %%
dfEpisodeNewFinal.set_index(["tconst"]).index.is_unique

# %% [markdown]
# ## Dropping columns and converting datasets to csv files - akas

# %%
movie_alias_final = movie_alias.drop(columns=["language", "types", "attributes"], axis = 1)
movie_alias_final.to_csv("Final CSV Files/movie_alias.tsv", encoding="utf-8", sep="\t", index=False)

# %%
series_alias_final = series_alias.drop(columns=["language", "types", "attributes"], axis = 1)
series_alias_final.to_csv("Final CSV Files/series_alias.tsv", encoding="utf-8", sep="\t", index=False)

# %%
episode_alias_final = episode_alias.drop(columns=["language", "types", "attributes"], axis = 1)
episode_alias_final.to_csv("Final CSV Files/episode_alias.tsv", encoding="utf-8", sep="\t", index=False)

# %% [markdown]
# ## Dropping columns and converting datasets to csv files - name basic

# %% [markdown]
# ### Actor

# %%
df_actor_final_new = df4_final_actor_actress.drop(columns=["primaryProfession"], axis = 1)

# %%
df_actor_knownForTitles = df_actor_final_new[["nconst", "knownForTitles"]]
df_actor_knownForTitles = df_actor_knownForTitles[df_actor_knownForTitles["knownForTitles"] != "\\N"]
df_actor_knownForTitles = pd.DataFrame(df_actor_knownForTitles.knownForTitles.str.split(',')
                                          .tolist(), index=df_actor_knownForTitles.nconst).stack()
df_actor_knownForTitles = df_actor_knownForTitles.reset_index()[['nconst', 0]] 
df_actor_knownForTitles.columns = ['nconst', 'knownForTitles']

# %%
df_actor_knownForTitles.to_csv("Final CSV Files/actorknownfortitles.tsv", encoding="utf-8", sep="\t", index=False)

# %%
df_actor_final_new.drop(columns = ["knownForTitles"], axis = 1, inplace=True)

# %%
df_actor_final_new.to_csv("Final CSV Files/actor.tsv", encoding="utf-8", sep="\t", index=False)

# %% [markdown]
# ### Director

# %%
df_director_final_new = df4_final_director.drop(columns=["primaryProfession"], axis = 1)

# %%
df_director_knownForTitles = df_director_final_new[["nconst", "knownForTitles"]]
df_director_knownForTitles = df_director_knownForTitles[df_director_knownForTitles["knownForTitles"] != "\\N"]
df_director_knownForTitles = pd.DataFrame(df_director_knownForTitles.knownForTitles.str.split(',')
                                          .tolist(), index=df_director_knownForTitles.nconst).stack()
df_director_knownForTitles = df_director_knownForTitles.reset_index()[['nconst', 0]] 
df_director_knownForTitles.columns = ['nconst', 'knownForTitles']

# %%
df_director_knownForTitles.to_csv("Final CSV Files/directorknownfortitles.tsv", encoding="utf-8", sep="\t", index=False)

# %%
df_director_final_new.drop(columns = ["knownForTitles"], axis = 1, inplace=True)

# %%
df_director_final_new.to_csv("Final CSV Files/director.tsv", encoding="utf-8", sep="\t", index=False)

# %% [markdown]
# ### Writer

# %%
df_writer_final_new = df4_final_writer.drop(columns=["primaryProfession"], axis = 1)

# %%
df_writer_knownForTitles = df_writer_final_new[["nconst", "knownForTitles"]]
df_writer_knownForTitles = df_writer_knownForTitles[df_writer_knownForTitles["knownForTitles"] != "\\N"]
df_writer_knownForTitles = pd.DataFrame(df_writer_knownForTitles.knownForTitles.str.split(',')
                                          .tolist(), index=df_writer_knownForTitles.nconst).stack()
df_writer_knownForTitles = df_writer_knownForTitles.reset_index()[['nconst', 0]] 
df_writer_knownForTitles.columns = ['nconst', 'knownForTitles']

# %%
df_writer_knownForTitles.to_csv("Final CSV Files/writerknownfortitles.tsv", encoding="utf-8", sep="\t", index=False)

# %%
df_writer_final_new.drop(columns = ["knownForTitles"], axis = 1, inplace=True)

# %%
df_writer_final_new.to_csv("Final CSV Files/writer.tsv", encoding="utf-8", sep="\t", index=False)

# %% [markdown]
# ### Dropping columns and converting datasets to csv files - name basic

# %% [markdown]
# # All relations related to movie

# %%
dfActorMovieRelation.drop(['category'],inplace = True, axis = 1)

# %%
dfActorMovieRelation.to_csv("Final CSV Files/movie_actor_relation.tsv", encoding="utf-8", sep="\t", index=False)

# %%
dfDirectorMovieRelation.drop(['category','characters'],inplace = True, axis = 1)
# .drop(['category'],inplace = True, axis = 1)

# %%
dfDirectorMovieRelation.to_csv("Final CSV Files/movie_director_relation.tsv", encoding="utf-8", sep="\t", index=False)

# %%
dfWriterMovieRelation.drop(['category','characters'],inplace = True, axis = 1)

# %%
dfWriterMovieRelation.to_csv("Final CSV Files/movie_writer_relation.tsv", encoding="utf-8", sep="\t", index=False)

# %% [markdown]
# # All relations related to series

# %%
dfActorSeriesRelation.drop(['category'],inplace = True, axis = 1)

# %%
dfActorSeriesRelation.to_csv("Final CSV Files/series_actor_relation.tsv", encoding="utf-8", sep="\t", index=False)

# %%
dfDirectorSeriesRelation.drop(['category','characters'],inplace = True, axis = 1)

# %%
dfDirectorSeriesRelation.to_csv("Final CSV Files/series_director_relation.tsv", encoding="utf-8", sep="\t", index=False)

# %%
dfWriterSeriesRelation.drop(['category','characters'],inplace = True, axis = 1)

# %%
dfWriterSeriesRelation.to_csv("Final CSV Files/series_writer_relation.tsv", encoding="utf-8", sep="\t", index=False)

# %% [markdown]
# ## genre

# %%
df_movie_genre
df_series_genre.genres.value_counts()

# %%
df_movie_genre.to_csv("Final CSV Files/movie_genre.tsv", encoding="utf-8", sep="\t", index=False)

# %%
df_series_genre.to_csv("Final CSV Files/series_genre.tsv", encoding="utf-8", sep="\t", index=False)
